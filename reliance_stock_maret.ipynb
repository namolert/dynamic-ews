# %%
import numpy as np
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

# --- Load Example Data (Daily Returns) ---
# Replace this with your actual financial returns data (e.g., S&P 500, FTSE)
# Example: Generating dummy returns for illustration
np.random.seed(420)
returns = np.random.normal(0, 0.02, 1000)  # 1000 days of synthetic returns
returns = pd.Series(returns)

# --- Define VaR confidence level ---
alpha = 0.05  # 5% VaR

# --- Simple Model 1: GARCH(1,1) VaR ---
garch = arch_model(returns, vol='Garch', p=1, q=1)
garch_result = garch.fit(disp='off')

garch_var_list = []
for i in range(500, len(returns)):  # Rolling forecast starting from day 500
    rolling_data = returns[:i]
    model = arch_model(rolling_data, vol='Garch', p=1, q=1)
    result = model.fit(disp='off')
    forecast_var = result.forecast(horizon=1).variance.values[-1][0]
    garch_var = -1.65 * np.sqrt(forecast_var)  # For 5% one-day VaR
    garch_var_list.append(garch_var)

# --- Simple Model 2: Historical Simulation VaR ---
hist_var_list = []
window_size = 500
for i in range(window_size, len(returns)):
    hist_window = returns[i-window_size:i]
    hist_var = np.percentile(hist_window, 100 * alpha)  # 5% Historical VaR
    hist_var_list.append(hist_var)

# --- Forecast Combination: Simple Average of GARCH and Historical VaR ---
combined_var_list = []
for garch_v, hist_v in zip(garch_var_list, hist_var_list):
    combined_var = (garch_v + hist_v) / 2
    combined_var_list.append(combined_var)

# --- Compare VaR Forecasts ---
forecast_dates = np.arange(window_size, len(returns))
plt.figure(figsize=(10, 5))
plt.plot(forecast_dates, garch_var_list, label='GARCH VaR', color='blue')
plt.plot(forecast_dates, hist_var_list, label='Historical VaR', color='green')
plt.plot(forecast_dates, combined_var_list, label='Combined VaR', color='red', linestyle='--')
plt.title('5% One-Day VaR Forecast: Single Models vs Forecast Combination')
plt.xlabel('Day')
plt.ylabel('VaR Level')
plt.legend()
plt.tight_layout()
plt.show()

# --- Simple Backtesting: VaR Violations ---
actual_returns = returns[window_size:]

garch_violations = np.sum(actual_returns.values < np.array(garch_var_list))
hist_violations = np.sum(actual_returns.values < np.array(hist_var_list))
combined_violations = np.sum(actual_returns.values < np.array(combined_var_list))

print(f"GARCH VaR violations: {garch_violations}")
print(f"Historical VaR violations: {hist_violations}")
print(f"Combined VaR violations: {combined_violations}")
# Out:
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003987. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003821. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003814. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003808. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000384. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003842. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003862. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003865. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000386. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003859. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003852. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003886. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000389. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003916. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003921. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003971. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004007. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004014. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004014. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004008. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004003. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003995. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003994. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004002. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003995. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004006. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003998. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004004. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004007. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004001. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004022. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004037. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004033. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004026. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004024. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004016. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000401. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004049. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004062. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004056. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004054. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000411. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004106. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004112. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004105. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004114. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004137. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004138. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004131. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004131. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004125. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004119. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004133. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004145. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000414. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004134. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004129. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004127. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004127. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004119. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004125. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004121. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004115. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000411. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004106. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004105. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.00041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004101. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004094. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000409. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004083. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004081. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004081. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004075. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004068. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004062. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004057. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000405. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004042. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004054. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004048. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004045. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000404. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004051. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004049. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004044. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004041. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004035. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004056. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004053. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004054. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004048. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004042. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004043. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004037. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0004056. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# ...
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000398. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003976. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003974. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003971. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003967. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003964. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.000396. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003956. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003952. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003949. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003945. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003955. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003951. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003956. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003956. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003959. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003985. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003979. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003987. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003991. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003988. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003984. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003982. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003983. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003979. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003976. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003998. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003997. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003993. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# c:\Users\namo\AppData\Local\Programs\Python\Python311\Lib\site-packages\arch\univariate\base.py:309: DataScaleWarning: y is poorly scaled, which may affect convergence of the optimizer when
# estimating the model parameters. The scale of y is 0.0003989. Parameter
# estimation work better when this value is between 1 and 1000. The recommended
# rescaling is 100 * y.
#
# This warning can be disabled by either rescaling y before initializing the
# model or by setting rescale=False.
#
#   warnings.warn(
# GARCH VaR violations: 23
# Historical VaR violations: 30
# Combined VaR violations: 26
